# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
# create engine to hawaii.sqlite
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# base declaration
Base = automap_base()

# %%
# base prep before reflect
Base.prepare(autoload_with=engine)

# %%
# reflect an existing database into a new model
measure = Base.classes.measurement
station = Base.classes.station
# reflect the table

# %%
# View all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Precipitation Analysis

# %%
# import inspection tool
from sqlalchemy import inspect

# %%
# explore the engine and tables
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['measurement', 'station']

# %%
# what's in the first table?
columns = inspector.get_columns('measurement')
for column in columns:
    print(column["name"], column["type"])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
# what's in the second table?
columns = inspector.get_columns('station')
for column in columns:
    print(column["name"], column["type"])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
#for row in session.query(measure, measure.date).all():
#    print(row)
#session.query(func.count(measure.date)).all()
earliestDate = session.query(measure.date).order_by(measure.date).first()
latestDate = session.query(measure.date).order_by(measure.date.desc()).first()

# %%
import datetime as dt

# %%
# Find the most recent date in the data set.
ymd = latestDate.date.split('-')
finalDate = dt.date(int(ymd[0]), int(ymd[1]), int(ymd[2]))

pastYear = dt.date(2016, int(ymd[1]), int(ymd[2]))


# latestDateDt = dt(int(latestDate))

# latestDateDt = dt(int(latestDate))

# %%
week_ago = dt.date.today() - dt.timedelta(days=7)

# %%
print(finalDate)
pastYear
# Out:
# 2017-08-23
# datetime.date(2016, 8, 23)

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results. 
# Starting from the most recent data point in the database. 
session.query(measure.date).\
    filter(pastYear >= measure.date).\
    filter(measure.date <= finalDate).\
    order_by(measure.date).all()

# Calculate the date one year from the last date in data set.


# Perform a query to retrieve the data and precipitation scores


# Save the query results as a Pandas DataFrame and set the index to the date column


# Sort the dataframe by date


# Use Pandas Plotting with Matplotlib to plot the data
# Out:
# [('2010-01-01',),
#  ('2010-01-01',),
#  ('2010-01-01',),
#  ('2010-01-01',),
#  ('2010-01-01',),
#  ('2010-01-01',),
#  ('2010-01-01',),
#  ('2010-01-02',),
#  ('2010-01-02',),
#  ('2010-01-02',),
#  ('2010-01-02',),
#  ('2010-01-02',),
#  ('2010-01-02',),
#  ('2010-01-02',),
#  ('2010-01-03',),
#  ('2010-01-03',),
#  ('2010-01-03',),
#  ('2010-01-03',),
#  ('2010-01-03',),
#  ('2010-01-03',),
#  ('2010-01-03',),
#  ('2010-01-04',),
#  ('2010-01-04',),
#  ('2010-01-04',),
#  ('2010-01-04',),
#  ('2010-01-04',),
#  ('2010-01-04',),
#  ('2010-01-04',),
#  ('2010-01-05',),
#  ('2010-01-05',),
#  ('2010-01-05',),
#  ('2010-01-05',),
#  ('2010-01-05',),
#  ('2010-01-05',),
#  ('2010-01-06',),
#  ('2010-01-06',),
#  ('2010-01-06',),
#  ('2010-01-06',),
#  ('2010-01-06',),
#  ('2010-01-06',),
#  ('2010-01-07',),
#  ('2010-01-07',),
#  ('2010-01-07',),
#  ('2010-01-07',),
#  ('2010-01-07',),
#  ('2010-01-07',),
#  ('2010-01-07',),
#  ('2010-01-08',),
#  ('2010-01-08',),
#  ('2010-01-08',),
# ...

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data

# %% [markdown]
# # Exploratory Station Analysis

# %%
# Design a query to calculate the total number stations in the dataset
session.query(func.count(station.id)).all()
# Out:
# [(9,)]

# %%
# Design a query to find the most active stations (i.e. what stations have the most rows?)
# List the stations and the counts in descending order.

# %%
# Using the most active station id from the previous query, calculate the lowest, highest, and average temperature.

# %%
# Using the most active station id
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram

# %% [markdown]
# # Close session

# %%
# Close Session
session.close()
